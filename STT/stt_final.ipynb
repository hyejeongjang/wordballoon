# %%
import re
from google.cloud import speech
import io
import os

path = 'video_eng2.mp3'

client = speech.SpeechClient()

# path = 'resources/commercial_mono.wav'
with io.open(path, 'rb') as audio_file:
    content = audio_file.read()

audio = speech.types.RecognitionAudio(content=content)
config = speech.types.RecognitionConfig(
    encoding=speech.enums.RecognitionConfig.AudioEncoding.ENCODING_UNSPECIFIED,
    sample_rate_hertz=8000,
    language_code='en-US',
    # Enable automatic punctuation
    enable_automatic_punctuation=True)

response = client.recognize(config, audio)
tmp = []

for i, result in enumerate(response.results):
    alternative = result.alternatives[0]
    print('-' * 20)
    print('First alternative of result {}'.format(i))
    print('Transcript: {}'.format(alternative.transcript))
    output = re.split('([.,?!])', alternative.transcript)
    del output[-1]
    tmp.append(output)
tmp
# Out:
# --------------------
# First alternative of result 0
# Transcript: How did Noah Sentinel become an actor of Jim advisor just watch sister wanted to audition for an agency that helps you get another agency. They were like a starter agency and when she wanted to audition. I just wanted to go play soccer and my parents said no, we're not hiring a babysitter going to come with and support your sister. So then when I got there, they asked me if I was going to do shit. And I said No, and then they said no you'd be good at this and I was like, okay, I'll try it and I tried it and I loved it and I never sucked.
# --------------------
# First alternative of result 1
# Transcript: How to get Noah since nail hair mother's simple now, so we're kind of your head super simple.
# --------------------
# First alternative of result 2
# Transcript:  What is 1 what is the Lock on De La NE Country as a human being a human girl woman? Not a bird agent or I'm 22 years young. So yeah, that's it was is Lana Condor? Snapchat know I do I never on it, but I do have it what movies has long been with them.
# --------------------
# First alternative of result 3
# Transcript:  Gosh, I think I was like 18 if you are 18, we're here at the same time, you know, everything working. I'll either be in the same your line fact. We have pretty much the same birthday your time 11.
# --------------------
# First alternative of result 4
# Transcript:  Your 99 11, but what we will work together, we would always work on her birthday. So we would celebrate our birthdays together. You know, you remember how you got a cake and I got a cup cakes.
# --------------------
# First alternative of result 5
# Transcript:  full of cupcakes
# [['How did Noah Sentinel become an actor of Jim advisor just watch sister wanted to audition for an agency that helps you get another agency',
#   '.',
#   ' They were like a starter agency and when she wanted to audition',
#   '.',
#   ' I just wanted to go play soccer and my parents said no',
#   ',',
#   " we're not hiring a babysitter going to come with and support your sister",
#   '.',
#   ' So then when I got there',
#   ',',
#   ' they asked me if I was going to do shit',
#   '.',
#   ' And I said No',
#   ',',
#   " and then they said no you'd be good at this and I was like",
#   ',',
#   ' okay',
#   ',',
#   " I'll try it and I tried it and I loved it and I never sucked",
#   '.'],
#  ["How to get Noah since nail hair mother's simple now",
#   ',',
#   " so we're kind of your head super simple",
#   '.'],
#  [' What is 1 what is the Lock on De La NE Country as a human being a human girl woman',
#   '?',
#   " Not a bird agent or I'm 22 years young",
#   '.',
#   ' So yeah',
#   ',',
#   " that's it was is Lana Condor",
#   '?',
#   ' Snapchat know I do I never on it',
#   ',',
#   ' but I do have it what movies has long been with them',
#   '.'],
#  [' Gosh',
#   ',',
#   ' I think I was like 18 if you are 18',
#   ',',
#   " we're here at the same time",
#   ',',
#   ' you know',
#   ',',
#   ' everything working',
#   '.',
#   " I'll either be in the same your line fact",
#   '.',
#   ' We have pretty much the same birthday your time 11',
#   '.'],
#  [' Your 99 11',
#   ',',
#   ' but what we will work together',
#   ',',
#   ' we would always work on her birthday',
#   '.',
#   ' So we would celebrate our birthdays together',
#   '.',
#   ' You know',
#   ',',
#   ' you remember how you got a cake and I got a cup cakes',
#   '.'],
#  []]

# %%
answer = sum(tmp, [])
answer
# Out:
# ['How did Noah Sentinel become an actor of Jim advisor just watch sister wanted to audition for an agency that helps you get another agency',
#  '.',
#  ' They were like a starter agency and when she wanted to audition',
#  '.',
#  ' I just wanted to go play soccer and my parents said no',
#  ',',
#  " we're not hiring a babysitter going to come with and support your sister",
#  '.',
#  ' So then when I got there',
#  ',',
#  ' they asked me if I was going to do shit',
#  '.',
#  ' And I said No',
#  ',',
#  " and then they said no you'd be good at this and I was like",
#  ',',
#  ' okay',
#  ',',
#  " I'll try it and I tried it and I loved it and I never sucked",
#  '.',
#  "How to get Noah since nail hair mother's simple now",
#  ',',
#  " so we're kind of your head super simple",
#  '.',
#  ' What is 1 what is the Lock on De La NE Country as a human being a human girl woman',
#  '?',
#  " Not a bird agent or I'm 22 years young",
#  '.',
#  ' So yeah',
#  ',',
#  " that's it was is Lana Condor",
#  '?',
#  ' Snapchat know I do I never on it',
#  ',',
#  ' but I do have it what movies has long been with them',
#  '.',
#  ' Gosh',
#  ',',
#  ' I think I was like 18 if you are 18',
#  ',',
#  " we're here at the same time",
#  ',',
#  ' you know',
#  ',',
#  ' everything working',
#  '.',
#  " I'll either be in the same your line fact",
#  '.',
#  ' We have pretty much the same birthday your time 11',
#  '.',
#  ' Your 99 11',
#  ',',
#  ' but what we will work together',
#  ',',
#  ' we would always work on her birthday',
#  '.',
#  ' So we would celebrate our birthdays together',
#  '.',
#  ' You know',
#  ',',
#  ' you remember how you got a cake and I got a cup cakes',
#  '.']

# %%
final=[]
for i in range(len(answer)):
    if i % 2 == 1:
        text1 = answer[i-1]+answer[i]
        final.append(text1)
final

f = open("output2.txt", 'a')

for i in final:
    print(i)
    f.write(i+"\n")
# f.writelines(output)
f.close()
# Out:
# How did Noah Sentinel become an actor of Jim advisor just watch sister wanted to audition for an agency that helps you get another agency.
#  They were like a starter agency and when she wanted to audition.
#  I just wanted to go play soccer and my parents said no,
#  we're not hiring a babysitter going to come with and support your sister.
#  So then when I got there,
#  they asked me if I was going to do shit.
#  And I said No,
#  and then they said no you'd be good at this and I was like,
#  okay,
#  I'll try it and I tried it and I loved it and I never sucked.
# How to get Noah since nail hair mother's simple now,
#  so we're kind of your head super simple.
#  What is 1 what is the Lock on De La NE Country as a human being a human girl woman?
#  Not a bird agent or I'm 22 years young.
#  So yeah,
#  that's it was is Lana Condor?
#  Snapchat know I do I never on it,
#  but I do have it what movies has long been with them.
#  Gosh,
#  I think I was like 18 if you are 18,
#  we're here at the same time,
#  you know,
#  everything working.
#  I'll either be in the same your line fact.
#  We have pretty much the same birthday your time 11.
#  Your 99 11,
#  but what we will work together,
#  we would always work on her birthday.
#  So we would celebrate our birthdays together.
#  You know,
#  you remember how you got a cake and I got a cup cakes.
